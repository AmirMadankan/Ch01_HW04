# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('/content/sample_data/california_housing_train.csv')

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
df_x = df.drop(labels=["median_house_value"], axis=1)

# %%
df_y = df["median_house_value"]

# %%
plt.scatter(df_x['longitude'], df_y)
plt.title('longitude - median house value')
plt.xlabel('longitude')
plt.ylabel('median house value')
plt.show()

# %%
plt.scatter(df_x['latitude'], df_y)
plt.title('latitude - median house value')
plt.xlabel('latitude')
plt.ylabel('median house value')
plt.show()

# %%
plt.scatter(df_x['housing_median_age'], df_y)
plt.title('housing median age - median house value')
plt.xlabel('housing median age')
plt.ylabel('median house value')
plt.show()

# %%
plt.scatter(df_x['total_rooms'], df_y)
plt.title('total rooms - median house value')
plt.xlabel('total rooms')
plt.ylabel('median house value')
plt.show()

# %%
plt.scatter(df_x['total_bedrooms'], df_y)
plt.title('total bedrooms - median house value')
plt.xlabel('total bedrooms')
plt.ylabel('median house value')
plt.show()

# %%
plt.scatter(df_x['population'], df_y)
plt.title('population - median house value')
plt.xlabel('population')
plt.ylabel('median house value')
plt.show()

# %%
plt.scatter(df_x['households'], df_y)
plt.title('households - median house value')
plt.xlabel('households')
plt.ylabel('median house value')
plt.show()

# %%
plt.scatter(df_x['median_income'], df_y)
plt.title('median income - median house value')
plt.xlabel('median income')
plt.ylabel('median house value')
plt.show()

# %%
model = LinearRegression()

# %%
model.fit(df_x, df_y)
# Out:
# LinearRegression()

# %%
model.score(df_x, df_y)
# Out:
# 0.6413378529502687

# %%
# longitude removed
df_x1 = df_x.drop(labels=['longitude'], axis=1)
df_x2 = df_x.drop(labels=['latitude'], axis=1)
df_x3 = df_x.drop(labels=['housing_median_age'], axis=1)
df_x4 = df_x.drop(labels=['total_rooms'], axis=1)
df_x5 = df_x.drop(labels=['total_bedrooms'], axis=1)
df_x6 = df_x.drop(labels=['population'], axis=1)
df_x7 = df_x.drop(labels=['households'], axis=1)
df_x8 = df_x.drop(labels=['median_income'], axis=1)

# %%
model1 = LinearRegression()
model2 = LinearRegression()
model3 = LinearRegression()
model4 = LinearRegression()
model5 = LinearRegression()
model6 = LinearRegression()
model7 = LinearRegression()
model8 = LinearRegression()

# %%
model1.fit(df_x1, df_y)
model2.fit(df_x2, df_y)
model3.fit(df_x3, df_y)
model4.fit(df_x4, df_y)
model5.fit(df_x5, df_y)
model6.fit(df_x6, df_y)
model7.fit(df_x7, df_y)
model8.fit(df_x8, df_y)
# Out:
# LinearRegression()

# %%
print("without longitude")
print(round(model1.score(df_x1, df_y), 3))
# Out:
# without longitude
# 0.578

# %%
print("without latitude")
print(round(model2.score(df_x2, df_y), 3))
# Out:
# without latitude
# 0.571

# %%
print("without housing_median_age")
print(round(model3.score(df_x3, df_y), 3))
# Out:
# without housing_median_age
# 0.629

# %%
print("without total_rooms")
print(round(model4.score(df_x4, df_y), 3))
# Out:
# without total_rooms
# 0.639

# %%
print("without total_bedrooms")
print(round(model5.score(df_x5, df_y), 3))
# Out:
# without total_bedrooms
# 0.636

# %%
print("without population")
print(round(model6.score(df_x6, df_y), 3))
# Out:
# without population
# 0.619

# %%
print("without households")
print(round(model7.score(df_x7, df_y), 3))
# Out:
# without households
# 0.641

# %%
print("without median_income")
print(round(model8.score(df_x8, df_y), 3))
# Out:
# without median_income
# 0.386

# %%
print("the model is most accurate, without households")
print("and the score is", round(model7.score(df_x7, df_y), 3))
# Out:
# the model is most accurate, without households
# and the score is 0.641

# %%
a = []
b = []
c = []
model_new = LinearRegression() 
for item1 in df_x:
  for item2 in df_x.drop(labels=[item1], axis=1):
    b.append(item1)
    c.append(item2)
    df_x_new = df_x.drop(labels=[item1, item2], axis=1)
    model_new.fit(df_x_new, df_y)
    a.append(model_new.score(df_x_new, df_y))
n = a.index(max(a))
print("The model is most accarate, without", b[n],'and', c[n])
print("and the score is", round(max(a), 2))
# Out:
# The model is most accarate, without total_rooms and households
# and the score is 0.64
